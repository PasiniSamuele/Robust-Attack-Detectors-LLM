# %%
import sys
sys.path.insert(0,'/workspaces/RAG_secure_code_generation/src')
sys.path.insert(0,'/workspaces/RAG_secure_code_generation')
import pandas as pd
import seaborn as sns
import os
import matplotlib.pyplot as plt
import json
import numpy as np

# %%
sns.color_palette("hls", 8)
# Out:
# [(0.86, 0.3712, 0.33999999999999997),
#  (0.86, 0.7612000000000001, 0.33999999999999997),
#  (0.5688000000000001, 0.86, 0.33999999999999997),
#  (0.33999999999999997, 0.86, 0.5012000000000001),
#  (0.33999999999999997, 0.8287999999999999, 0.86),
#  (0.33999999999999997, 0.43879999999999986, 0.86),
#  (0.6311999999999998, 0.33999999999999997, 0.86),
#  (0.86, 0.33999999999999997, 0.6987999999999996)]

# %%
summary_file = "../../experiments/task_detect_xss_simple_prompt/experiments_summary.csv"

# %%
df = pd.read_csv(summary_file)
df.head()
# Out:
#    Unnamed: 0  successes  failures  total  accuracy  accuracy_std  \
# 0           0         50         0     50  0.718765      0.148206
# 1           1         50         0     50  0.738455      0.134767
# 2           2         47         3     50  0.678764      0.165826
# 3           3         49         1     50  0.788162      0.159201
# 4           4         44         6     50  0.752529      0.164416
#
#    accuracy_var  precision  precision_std  precision_var  ...  \
# 0      0.021965   0.928139       0.138496       0.019181  ...
# 1      0.018162   0.917520       0.134003       0.017957  ...
# 2      0.027498   0.961529       0.119094       0.014183  ...
# 3      0.025345   0.956744       0.101042       0.010210  ...
# 4      0.027033   0.937666       0.092455       0.008548  ...
#
#    top_15_accuracy_var  top_15_precision  top_15_precision_std  \
# 0             0.002311          0.923941              0.098112
# 1             0.001109          0.918561              0.100400
# 2             0.004680          0.999350              0.002054
# 3             0.000318          0.997484              0.008984
# 4             0.003578          0.943870              0.092799
#
#    top_15_precision_var  top_15_recall  top_15_recall_std top_15_recall_var  \
# 0              0.009626       0.852387           0.111139          0.012352
# 1              0.010080       0.815788           0.126191          0.015924
# 2              0.000004       0.778447           0.135320          0.018312
# 3              0.000081       0.905528           0.035530          0.001262
# 4              0.008612       0.914042           0.088755          0.007877
#
#   top_15_f1 top_15_f1_std  top_15_f1_var
# 0  0.876072      0.051881       0.002692
# 1  0.850058      0.040719       0.001658
# 2  0.868435      0.088921       0.007907
# 3  0.948879      0.019180       0.000368
# 4  0.922441      0.059281       0.003514
#
# [5 rows x 111 columns]

# %%
top_n = 10

# %%
#set examples_per_class to 0 everytime generation_mode = zero_shot
df.loc[df['generation_mode'] == 'zero_shot', 'examples_per_class'] = 0

# %%
df = df[['model_name', 'temperature', 'examples_per_class', 'folder']]

# %%
def from_folder_to_accuracy_list(folder:str)->list:
    folder = os.path.join('../..', folder)
    #find all the subfolder in folder:
    subfolders = [f.path for f in os.scandir(folder) if f.is_dir() ]
    #map subfolder to the dict conteined in results.json file
    results = []
    for subfolder in subfolders:
        with open(os.path.join(subfolder, 'results.json')) as f:
            results.append(json.load(f))
    #keep only the results where failed is False
    results = [r for r in results if not r['failed']]
    #map results to accuracy
    results = [r['results']['accuracy'] for r in results]
    top_2_idx = np.argsort(results)[-top_n:]
    top_2_values = [results[i] for i in top_2_idx]
    return results_ordered

# %%
df.head()
# Out:
#            model_name  temperature  examples_per_class  \
# 0  gpt-4-1106-preview          0.5                   0
# 1  gpt-4-1106-preview          0.0                   0
# 2  gpt-4-1106-preview          1.0                   0
# 3  gpt-4-1106-preview          0.5                  10
# 4  gpt-4-1106-preview          0.0                  10
#
#                                               folder
# 0  experiments/task_detect_xss_simple_prompt/temp...
# 1  experiments/task_detect_xss_simple_prompt/temp...
# 2  experiments/task_detect_xss_simple_prompt/temp...
# 3  experiments/task_detect_xss_simple_prompt/temp...
# 4  experiments/task_detect_xss_simple_prompt/temp...

# %%
df['accuracy'] = df['folder'].map(from_folder_to_accuracy_list)

# %%
df.head()
# Out:
#            model_name  temperature  examples_per_class  \
# 0  gpt-4-1106-preview          0.5                   0
# 1  gpt-4-1106-preview          0.0                   0
# 2  gpt-4-1106-preview          1.0                   0
# 3  gpt-4-1106-preview          0.5                  10
# 4  gpt-4-1106-preview          0.0                  10
#
#                                               folder  \
# 0  experiments/task_detect_xss_simple_prompt/temp...
# 1  experiments/task_detect_xss_simple_prompt/temp...
# 2  experiments/task_detect_xss_simple_prompt/temp...
# 3  experiments/task_detect_xss_simple_prompt/temp...
# 4  experiments/task_detect_xss_simple_prompt/temp...
#
#                                             accuracy
# 0  [37, 22, 10, 18, 11, 24, 20, 46, 27, 44, 48, 4...
# 1  [3, 22, 41, 26, 47, 29, 13, 44, 10, 8, 35, 38,...
# 2  [27, 42, 21, 8, 26, 1, 2, 9, 41, 25, 4, 40, 22...
# 3  [19, 37, 25, 15, 44, 35, 21, 47, 6, 20, 41, 10...
# 4  [43, 4, 7, 25, 10, 6, 36, 17, 40, 42, 13, 2, 2...

# %%
#explode the accuracy list
df = df.explode('accuracy')
df.head()
# Out:
#            model_name  temperature  examples_per_class  \
# 0  gpt-4-1106-preview          0.5                   0
# 0  gpt-4-1106-preview          0.5                   0
# 0  gpt-4-1106-preview          0.5                   0
# 0  gpt-4-1106-preview          0.5                   0
# 0  gpt-4-1106-preview          0.5                   0
#
#                                               folder accuracy
# 0  experiments/task_detect_xss_simple_prompt/temp...       37
# 0  experiments/task_detect_xss_simple_prompt/temp...       22
# 0  experiments/task_detect_xss_simple_prompt/temp...       10
# 0  experiments/task_detect_xss_simple_prompt/temp...       18
# 0  experiments/task_detect_xss_simple_prompt/temp...       11

# %%
#reinitialize the index
df = df.reset_index(drop=False)
df.head()
# Out:
#    index          model_name  temperature  examples_per_class  \
# 0      0  gpt-4-1106-preview          0.5                   0
# 1      0  gpt-4-1106-preview          0.5                   0
# 2      0  gpt-4-1106-preview          0.5                   0
# 3      0  gpt-4-1106-preview          0.5                   0
# 4      0  gpt-4-1106-preview          0.5                   0
#
#                                               folder  accuracy
# 0  experiments/task_detect_xss_simple_prompt/temp...  0.703024
# 1  experiments/task_detect_xss_simple_prompt/temp...   0.74977
# 2  experiments/task_detect_xss_simple_prompt/temp...   0.84492
# 3  experiments/task_detect_xss_simple_prompt/temp...  0.636825
# 4  experiments/task_detect_xss_simple_prompt/temp...  0.845934

# %%
df["model_temperature"] = df["model_name"] + "_" + df["temperature"].astype(str)

# %%
df.examples_per_class.unique()
# Out:
# array([ 0, 10, 20,  2,  3,  1, 15,  5])

# %%
df.head()
# Out:
#    index          model_name  temperature  examples_per_class  \
# 0      0  gpt-4-1106-preview          0.5                   0
# 1      0  gpt-4-1106-preview          0.5                   0
# 2      0  gpt-4-1106-preview          0.5                   0
# 3      0  gpt-4-1106-preview          0.5                   0
# 4      0  gpt-4-1106-preview          0.5                   0
#
#                                               folder  accuracy  \
# 0  experiments/task_detect_xss_simple_prompt/temp...  0.703024
# 1  experiments/task_detect_xss_simple_prompt/temp...   0.74977
# 2  experiments/task_detect_xss_simple_prompt/temp...   0.84492
# 3  experiments/task_detect_xss_simple_prompt/temp...  0.636825
# 4  experiments/task_detect_xss_simple_prompt/temp...  0.845934
#
#         model_temperature
# 0  gpt-4-1106-preview_0.5
# 1  gpt-4-1106-preview_0.5
# 2  gpt-4-1106-preview_0.5
# 3  gpt-4-1106-preview_0.5
# 4  gpt-4-1106-preview_0.5

# %%
#draw boxplot  per model-temperature pair and examples_per_class
sns.set_theme(style="whitegrid")
#make figure larger
plt.figure(figsize=(20, 10))
ax = sns.boxplot(x="model_temperature", y="accuracy", hue="examples_per_class", data=df, palette="Spectral", legend = "full")
ax.set_xticklabels(ax.get_xticklabels(), rotation=30)
ax.set_xlabel("model_name, temperature")
ax.set_ylabel("accuracy")
#set legend using the hue values present in the dataset
plt.show()
# Out:
# /tmp/ipykernel_695730/4170341328.py:6: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=30)

# %%
#draw boxplot  per model-temperature pair and examples_per_class
hue_order = df.groupby('model_temperature')["model_temperature"].first().sort_values().index

sns.set_theme(style="whitegrid")
#make figure larger
plt.figure(figsize=(30, 8))
ax = sns.boxplot(x="examples_per_class", y="accuracy", hue="model_temperature", hue_order = hue_order,data=df, palette="Spectral", legend = "brief")
ax.set_xticklabels(ax.get_xticklabels(), rotation=30)
ax.set_xlabel("model_name, temperature")
ax.set_ylabel("accuracy")
#set legend using the hue values present in the dataset
plt.show()
# Out:
# /tmp/ipykernel_695730/1813412099.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=30)

# %%
#draw the catplot
sns.set_theme(style="whitegrid")
#make figure larger
plt.figure(figsize=(35, 15))
ax = sns.catplot(x="examples_per_class",col="model_temperature", y="accuracy", hue = "examples_per_class", kind="box", data=df, col_wrap =3, palette="Spectral")
#show legends with color
#set legend using the hue values present in the datase
#plt.legend(title='examples_per_class')
#plt.show()

# %%
hue_order = df.groupby('model_temperature')["model_temperature"].first().sort_values().index
#draw the catplot
sns.set_theme(style="whitegrid")
#make figure larger
plt.figure(figsize=(35, 15))
ax = sns.catplot(x="model_temperature",col="examples_per_class", y="accuracy", hue = "model_temperature", hue_order = hue_order, kind="box", data=df, col_wrap =2, palette="Spectral", legend="full")
#hide x labels
ax.set_xticklabels([])
#show legend
