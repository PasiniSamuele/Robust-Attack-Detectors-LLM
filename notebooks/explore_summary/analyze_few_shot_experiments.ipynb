# %%
import sys
sys.path.insert(0,'/workspaces/RAG_secure_code_generation/src')
sys.path.insert(0,'/workspaces/RAG_secure_code_generation')
import pandas as pd
import os

# %%
summary_file = "../../experiments/task_detect_xss_simple_prompt/experiments_summary.csv"
output = "../../output/few_shot_experiments_{examples}_examples.csv"

# %%
parameters_to_keep = [
    "model_name",
    "temperature",
    "successes",
    "accuracy",
    "precision",
    "recall",
    "f1",
    "examples_per_class"
]
examples_per_class = 20

# %%
seed = 156

# %%
output = output.format(examples=examples_per_class)
output
# Out:
# '../../output/few_shot_experiments_20_examples.csv'

# %%
df = pd.read_csv(summary_file)
df.head()
# Out:
#    Unnamed: 0  successes  failures  total  accuracy  accuracy_std  \
# 0           0         50         0     50  0.718765      0.148206
# 1           1         50         0     50  0.738455      0.134767
# 2           2         47         3     50  0.678764      0.165826
# 3           3         49         1     50  0.788162      0.159201
# 4           4         44         6     50  0.752529      0.164416
#
#    accuracy_var  precision  precision_std  precision_var  ...  \
# 0      0.021965   0.928139       0.138496       0.019181  ...
# 1      0.018162   0.917520       0.134003       0.017957  ...
# 2      0.027498   0.961529       0.119094       0.014183  ...
# 3      0.025345   0.956744       0.101042       0.010210  ...
# 4      0.027033   0.937666       0.092455       0.008548  ...
#
#    hf_max_new_tokens  hf_load_in_4bit  seed  \
# 0                400             True   156
# 1                400             True   156
# 2                400             True   156
# 3                400             True   156
# 4                400             True   156
#
#                                     example_template  examples_per_class  \
# 0  data/example_templates/detect_xss_simple_promp...                   0
# 1  data/example_templates/detect_xss_simple_promp...                   0
# 2  data/example_templates/detect_xss_simple_promp...                   0
# 3  data/example_templates/detect_xss_simple_promp...                  10
# 4  data/example_templates/detect_xss_simple_promp...                  10
#
#     examples_file examples_payload_column examples_label_column  \
# 0  data/train.csv                Payloads                 Class
# 1  data/train.csv                Payloads                 Class
# 2  data/train.csv                Payloads                 Class
# 3  data/train.csv                Payloads                 Class
# 4  data/train.csv                Payloads                 Class
#
#   example_positive_label example_negative_label
# 0              Malicious                 Benign
# 1              Malicious                 Benign
# 2              Malicious                 Benign
# 3              Malicious                 Benign
# 4              Malicious                 Benign
#
# [5 rows x 50 columns]

# %%
#keep only the rows with seed
df = df[df["seed"] == seed]
df.head()
# Out:
#    Unnamed: 0  successes  failures  total  accuracy  accuracy_std  \
# 0           0         50         0     50  0.718765      0.148206
# 1           1         50         0     50  0.738455      0.134767
# 2           2         47         3     50  0.678764      0.165826
# 3           3         49         1     50  0.788162      0.159201
# 4           4         44         6     50  0.752529      0.164416
#
#    accuracy_var  precision  precision_std  precision_var  ...  \
# 0      0.021965   0.928139       0.138496       0.019181  ...
# 1      0.018162   0.917520       0.134003       0.017957  ...
# 2      0.027498   0.961529       0.119094       0.014183  ...
# 3      0.025345   0.956744       0.101042       0.010210  ...
# 4      0.027033   0.937666       0.092455       0.008548  ...
#
#    hf_max_new_tokens  hf_load_in_4bit  seed  \
# 0                400             True   156
# 1                400             True   156
# 2                400             True   156
# 3                400             True   156
# 4                400             True   156
#
#                                     example_template  examples_per_class  \
# 0  data/example_templates/detect_xss_simple_promp...                   0
# 1  data/example_templates/detect_xss_simple_promp...                   0
# 2  data/example_templates/detect_xss_simple_promp...                   0
# 3  data/example_templates/detect_xss_simple_promp...                  10
# 4  data/example_templates/detect_xss_simple_promp...                  10
#
#     examples_file examples_payload_column examples_label_column  \
# 0  data/train.csv                Payloads                 Class
# 1  data/train.csv                Payloads                 Class
# 2  data/train.csv                Payloads                 Class
# 3  data/train.csv                Payloads                 Class
# 4  data/train.csv                Payloads                 Class
#
#   example_positive_label example_negative_label
# 0              Malicious                 Benign
# 1              Malicious                 Benign
# 2              Malicious                 Benign
# 3              Malicious                 Benign
# 4              Malicious                 Benign
#
# [5 rows x 50 columns]

# %%
#filter keeping only generation mode few_shot
df = df[df["generation_mode"] == "few_shot"]
df.head()
# Out:
#    Unnamed: 0  successes  failures  total  accuracy  accuracy_std  \
# 3           3         49         1     50  0.788162      0.159201
# 4           4         44         6     50  0.752529      0.164416
# 5           5         43         7     50  0.809243      0.143294
# 6           6         48         2     50  0.839732      0.133960
# 7           7         45         5     50  0.842596      0.171854
#
#    accuracy_var  precision  precision_std  precision_var  ...  \
# 3      0.025345   0.956744       0.101042       0.010210  ...
# 4      0.027033   0.937666       0.092455       0.008548  ...
# 5      0.020533   0.976206       0.064623       0.004176  ...
# 6      0.017945   0.960295       0.080615       0.006499  ...
# 7      0.029534   0.953071       0.088988       0.007919  ...
#
#    hf_max_new_tokens  hf_load_in_4bit  seed  \
# 3                400             True   156
# 4                400             True   156
# 5                400             True   156
# 6                400             True   156
# 7                400             True   156
#
#                                     example_template  examples_per_class  \
# 3  data/example_templates/detect_xss_simple_promp...                  10
# 4  data/example_templates/detect_xss_simple_promp...                  10
# 5  data/example_templates/detect_xss_simple_promp...                  10
# 6  data/example_templates/detect_xss_simple_promp...                  20
# 7  data/example_templates/detect_xss_simple_promp...                  20
#
#     examples_file examples_payload_column examples_label_column  \
# 3  data/train.csv                Payloads                 Class
# 4  data/train.csv                Payloads                 Class
# 5  data/train.csv                Payloads                 Class
# 6  data/train.csv                Payloads                 Class
# 7  data/train.csv                Payloads                 Class
#
#   example_positive_label example_negative_label
# 3              Malicious                 Benign
# 4              Malicious                 Benign
# 5              Malicious                 Benign
# 6              Malicious                 Benign
# 7              Malicious                 Benign
#
# [5 rows x 50 columns]

# %%
#filtering keeping only examples_per_class
df = df[df["examples_per_class"] == examples_per_class]
df.head()
# Out:
#     Unnamed: 0  successes  failures  total  accuracy  accuracy_std  \
# 6            6         48         2     50  0.839732  1.339603e-01
# 7            7         45         5     50  0.842596  1.718545e-01
# 8            8         50         0     50  0.848777  1.368889e-01
# 30          30         40        10     50  0.621538  1.613810e-01
# 31          31         44         6     50  0.499723  5.551115e-17
#
#     accuracy_var  precision  precision_std  precision_var  ...  \
# 6   1.794537e-02   0.960295       0.080615       0.006499  ...
# 7   2.953396e-02   0.953071       0.088988       0.007919  ...
# 8   1.873857e-02   0.954434       0.115510       0.013343  ...
# 30  2.604384e-02   0.974120       0.096611       0.009334  ...
# 31  3.081488e-33   1.000000       0.000000       0.000000  ...
#
#     hf_max_new_tokens  hf_load_in_4bit  seed  \
# 6                 400             True   156
# 7                 400             True   156
# 8                 400             True   156
# 30                400             True   156
# 31                400             True   156
#
#                                      example_template  examples_per_class  \
# 6   data/example_templates/detect_xss_simple_promp...                  20
# 7   data/example_templates/detect_xss_simple_promp...                  20
# 8   data/example_templates/detect_xss_simple_promp...                  20
# 30  data/example_templates/detect_xss_simple_promp...                  20
# 31  data/example_templates/detect_xss_simple_promp...                  20
#
#      examples_file examples_payload_column examples_label_column  \
# 6   data/train.csv                Payloads                 Class
# 7   data/train.csv                Payloads                 Class
# 8   data/train.csv                Payloads                 Class
# 30  data/train.csv                Payloads                 Class
# 31  data/train.csv                Payloads                 Class
#
#    example_positive_label example_negative_label
# 6               Malicious                 Benign
# 7               Malicious                 Benign
# 8               Malicious                 Benign
# 30              Malicious                 Benign
# 31              Malicious                 Benign
#
# [5 rows x 50 columns]

# %%
#keep only the parameters we want
df = df[parameters_to_keep]
df.head()
# Out:
#             model_name  temperature  successes  accuracy  precision    recall  \
# 6   gpt-4-1106-preview          0.5         48  0.839732   0.960295  0.723579
# 7   gpt-4-1106-preview          0.0         45  0.842596   0.953071  0.741714
# 8   gpt-4-1106-preview          1.0         50  0.848777   0.954434  0.765754
# 30  gpt-3.5-turbo-0613          0.5         40  0.621538   0.974120  0.290590
# 31  gpt-3.5-turbo-0613          0.0         44  0.499723   1.000000  0.010035
#
#           f1  examples_per_class
# 6   0.783808                  20
# 7   0.760115                  20
# 8   0.816611                  20
# 30  0.327998                  20
# 31  0.019870                  20

# %%
#set the precision of the metrics to 3f
df = df.round(3)
df.head()
# Out:
#             model_name  temperature  successes  accuracy  precision  recall  \
# 6   gpt-4-1106-preview          0.5         48     0.840      0.960   0.724
# 7   gpt-4-1106-preview          0.0         45     0.843      0.953   0.742
# 8   gpt-4-1106-preview          1.0         50     0.849      0.954   0.766
# 30  gpt-3.5-turbo-0613          0.5         40     0.622      0.974   0.291
# 31  gpt-3.5-turbo-0613          0.0         44     0.500      1.000   0.010
#
#        f1  examples_per_class
# 6   0.784                  20
# 7   0.760                  20
# 8   0.817                  20
# 30  0.328                  20
# 31  0.020                  20

# %%
#drop examples_per_class column
df = df.drop(columns=["examples_per_class"])
df.head()
# Out:
#             model_name  temperature  successes  accuracy  precision  recall  \
# 6   gpt-4-1106-preview          0.5         48     0.840      0.960   0.724
# 7   gpt-4-1106-preview          0.0         45     0.843      0.953   0.742
# 8   gpt-4-1106-preview          1.0         50     0.849      0.954   0.766
# 30  gpt-3.5-turbo-0613          0.5         40     0.622      0.974   0.291
# 31  gpt-3.5-turbo-0613          0.0         44     0.500      1.000   0.010
#
#        f1
# 6   0.784
# 7   0.760
# 8   0.817
# 30  0.328
# 31  0.020

# %%
#sort by model name and by temperature
df = df.sort_values(by=["model_name", "temperature"])
df.head()
# Out:
#             model_name  temperature  successes  accuracy  precision  recall  \
# 31  gpt-3.5-turbo-0613          0.0         44     0.500      1.000   0.010
# 30  gpt-3.5-turbo-0613          0.5         40     0.622      0.974   0.291
# 32  gpt-3.5-turbo-0613          1.0         46     0.623      0.930   0.342
# 7   gpt-4-1106-preview          0.0         45     0.843      0.953   0.742
# 6   gpt-4-1106-preview          0.5         48     0.840      0.960   0.724
#
#        f1
# 31  0.020
# 30  0.328
# 32  0.376
# 7   0.760
# 6   0.784

# %%
len(df)
# Out:
# 6

# %%
#save the dataframe
df.to_csv(output, index=False)
