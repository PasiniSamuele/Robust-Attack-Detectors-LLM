# %%
import sys
sys.path.insert(0,'/workspaces/RAG_secure_code_generation/src')
sys.path.insert(0,'/workspaces/RAG_secure_code_generation')
import pandas as pd
import os

# %%
seed = 156

# %%
summary_file = "../../experiments/task_detect_xss_simple_prompt/experiments_summary.csv"
output = "../../output/zero_shot_experiments.csv"

# %%
parameters_to_keep = [
    "model_name",
    "temperature",
    "successes",
    "accuracy",
    "precision",
    "recall",
    "f1"
]

# %%
df = pd.read_csv(summary_file)
df.head()
# Out:
#    Unnamed: 0  successes  failures  total  accuracy  accuracy_std  \
# 0           0         50         0     50  0.718765      0.148206
# 1           1         50         0     50  0.738455      0.134767
# 2           2         47         3     50  0.678764      0.165826
# 3           3         49         1     50  0.788162      0.159201
# 4           4         44         6     50  0.752529      0.164416
#
#    accuracy_var  precision  precision_std  precision_var  ...  \
# 0      0.021965   0.928139       0.138496       0.019181  ...
# 1      0.018162   0.917520       0.134003       0.017957  ...
# 2      0.027498   0.961529       0.119094       0.014183  ...
# 3      0.025345   0.956744       0.101042       0.010210  ...
# 4      0.027033   0.937666       0.092455       0.008548  ...
#
#    hf_max_new_tokens  hf_load_in_4bit  seed  \
# 0                400             True   156
# 1                400             True   156
# 2                400             True   156
# 3                400             True   156
# 4                400             True   156
#
#                                     example_template  examples_per_class  \
# 0  data/example_templates/detect_xss_simple_promp...                   0
# 1  data/example_templates/detect_xss_simple_promp...                   0
# 2  data/example_templates/detect_xss_simple_promp...                   0
# 3  data/example_templates/detect_xss_simple_promp...                  10
# 4  data/example_templates/detect_xss_simple_promp...                  10
#
#     examples_file examples_payload_column examples_label_column  \
# 0  data/train.csv                Payloads                 Class
# 1  data/train.csv                Payloads                 Class
# 2  data/train.csv                Payloads                 Class
# 3  data/train.csv                Payloads                 Class
# 4  data/train.csv                Payloads                 Class
#
#   example_positive_label example_negative_label
# 0              Malicious                 Benign
# 1              Malicious                 Benign
# 2              Malicious                 Benign
# 3              Malicious                 Benign
# 4              Malicious                 Benign
#
# [5 rows x 50 columns]

# %%
#keep only the rows with seed
df = df[df["seed"] == seed]
df.head()
# Out:
#    Unnamed: 0  successes  failures  total  accuracy  accuracy_std  \
# 0           0         50         0     50  0.718765      0.148206
# 1           1         50         0     50  0.738455      0.134767
# 2           2         47         3     50  0.678764      0.165826
# 3           3         49         1     50  0.788162      0.159201
# 4           4         44         6     50  0.752529      0.164416
#
#    accuracy_var  precision  precision_std  precision_var  ...  \
# 0      0.021965   0.928139       0.138496       0.019181  ...
# 1      0.018162   0.917520       0.134003       0.017957  ...
# 2      0.027498   0.961529       0.119094       0.014183  ...
# 3      0.025345   0.956744       0.101042       0.010210  ...
# 4      0.027033   0.937666       0.092455       0.008548  ...
#
#    hf_max_new_tokens  hf_load_in_4bit  seed  \
# 0                400             True   156
# 1                400             True   156
# 2                400             True   156
# 3                400             True   156
# 4                400             True   156
#
#                                     example_template  examples_per_class  \
# 0  data/example_templates/detect_xss_simple_promp...                   0
# 1  data/example_templates/detect_xss_simple_promp...                   0
# 2  data/example_templates/detect_xss_simple_promp...                   0
# 3  data/example_templates/detect_xss_simple_promp...                  10
# 4  data/example_templates/detect_xss_simple_promp...                  10
#
#     examples_file examples_payload_column examples_label_column  \
# 0  data/train.csv                Payloads                 Class
# 1  data/train.csv                Payloads                 Class
# 2  data/train.csv                Payloads                 Class
# 3  data/train.csv                Payloads                 Class
# 4  data/train.csv                Payloads                 Class
#
#   example_positive_label example_negative_label
# 0              Malicious                 Benign
# 1              Malicious                 Benign
# 2              Malicious                 Benign
# 3              Malicious                 Benign
# 4              Malicious                 Benign
#
# [5 rows x 50 columns]

# %%
#filter keeping only generation mode zero_shot
df = df[df["generation_mode"] == "zero_shot"]
df.head()
# Out:
#     Unnamed: 0  successes  failures  total  accuracy  accuracy_std  \
# 0            0         50         0     50  0.718765      0.148206
# 1            1         50         0     50  0.738455      0.134767
# 2            2         47         3     50  0.678764      0.165826
# 24          24         41         9     50  0.629563      0.152022
# 25          25         50         0     50  0.850358      0.000013
#
#     accuracy_var  precision  precision_std  precision_var  ...  \
# 0   2.196497e-02   0.928139       0.138496       0.019181  ...
# 1   1.816208e-02   0.917520       0.134003       0.017957  ...
# 2   2.749831e-02   0.961529       0.119094       0.014183  ...
# 24  2.311069e-02   0.949297       0.125045       0.015636  ...
# 25  1.666161e-10   1.000000       0.000000       0.000000  ...
#
#     hf_max_new_tokens  hf_load_in_4bit  seed  \
# 0                 400             True   156
# 1                 400             True   156
# 2                 400             True   156
# 24                400             True   156
# 25                400             True   156
#
#                                      example_template  examples_per_class  \
# 0   data/example_templates/detect_xss_simple_promp...                   0
# 1   data/example_templates/detect_xss_simple_promp...                   0
# 2   data/example_templates/detect_xss_simple_promp...                   0
# 24  data/example_templates/detect_xss_simple_promp...                   0
# 25  data/example_templates/detect_xss_simple_promp...                   0
#
#      examples_file examples_payload_column examples_label_column  \
# 0   data/train.csv                Payloads                 Class
# 1   data/train.csv                Payloads                 Class
# 2   data/train.csv                Payloads                 Class
# 24  data/train.csv                Payloads                 Class
# 25  data/train.csv                Payloads                 Class
#
#    example_positive_label example_negative_label
# 0               Malicious                 Benign
# 1               Malicious                 Benign
# 2               Malicious                 Benign
# 24              Malicious                 Benign
# 25              Malicious                 Benign
#
# [5 rows x 50 columns]

# %%
#keep only the parameters we want
df = df[parameters_to_keep]
df.head()
# Out:
#             model_name  temperature  successes  accuracy  precision    recall  \
# 0   gpt-4-1106-preview          0.5         50  0.718765   0.928139  0.500985
# 1   gpt-4-1106-preview          0.0         50  0.738455   0.917520  0.587962
# 2   gpt-4-1106-preview          1.0         47  0.678764   0.961529  0.398677
# 24  gpt-3.5-turbo-0613          0.5         41  0.629563   0.949297  0.324300
# 25  gpt-3.5-turbo-0613          0.0         50  0.850358   1.000000  0.703883
#
#           f1
# 0   0.573213
# 1   0.644007
# 2   0.476889
# 24  0.370793
# 25  0.826210

# %%
#set the precision of the metrics to 3f
df = df.round(3)
df.head()
# Out:
#             model_name  temperature  successes  accuracy  precision  recall  \
# 0   gpt-4-1106-preview          0.5         50     0.719      0.928   0.501
# 1   gpt-4-1106-preview          0.0         50     0.738      0.918   0.588
# 2   gpt-4-1106-preview          1.0         47     0.679      0.962   0.399
# 24  gpt-3.5-turbo-0613          0.5         41     0.630      0.949   0.324
# 25  gpt-3.5-turbo-0613          0.0         50     0.850      1.000   0.704
#
#        f1
# 0   0.573
# 1   0.644
# 2   0.477
# 24  0.371
# 25  0.826

# %%
#sort by model name and by temperature
df = df.sort_values(by=["model_name", "temperature"])
df.head()
# Out:
#             model_name  temperature  successes  accuracy  precision  recall  \
# 25  gpt-3.5-turbo-0613          0.0         50     0.850      1.000   0.704
# 24  gpt-3.5-turbo-0613          0.5         41     0.630      0.949   0.324
# 26  gpt-3.5-turbo-0613          1.0         42     0.579      0.944   0.199
# 1   gpt-4-1106-preview          0.0         50     0.738      0.918   0.588
# 0   gpt-4-1106-preview          0.5         50     0.719      0.928   0.501
#
#        f1
# 25  0.826
# 24  0.371
# 26  0.238
# 1   0.644
# 0   0.573

# %%
#save the dataframe
df.to_csv(output, index=False)
