# %%
import sys
sys.path.insert(0,'/workspaces/RAG_secure_code_generation/src')
sys.path.insert(0,'/workspaces/RAG_secure_code_generation')
import pandas as pd
import seaborn as sns
import os
import matplotlib.pyplot as plt
import json

# %%
sns.color_palette("hls", 8)
# Out:
# [(0.86, 0.3712, 0.33999999999999997),
#  (0.86, 0.7612000000000001, 0.33999999999999997),
#  (0.5688000000000001, 0.86, 0.33999999999999997),
#  (0.33999999999999997, 0.86, 0.5012000000000001),
#  (0.33999999999999997, 0.8287999999999999, 0.86),
#  (0.33999999999999997, 0.43879999999999986, 0.86),
#  (0.6311999999999998, 0.33999999999999997, 0.86),
#  (0.86, 0.33999999999999997, 0.6987999999999996)]

# %%
summary_file = "../../experiments/task_detect_xss_simple_prompt/experiments_summary.csv"

# %%
df = pd.read_csv(summary_file)
df.head()
# Out:
#    Unnamed: 0  successes  failures  total  accuracy  accuracy_std  \
# 0           0         26        24     50  0.824395      0.178259
# 1           1         48         2     50  0.810401      0.096359
# 2           2         50         0     50  0.753852      0.087768
# 3           3         41         9     50  0.857796      0.089478
# 4           4         46         4     50  0.821102      0.105810
#
#    accuracy_var  precision  precision_std  precision_var  ...  \
# 0      0.031776   0.912464       0.168308       0.028328  ...
# 1      0.009285   0.984112       0.048586       0.002361  ...
# 2      0.007703   0.986990       0.050529       0.002553  ...
# 3      0.008006   0.983858       0.079654       0.006345  ...
# 4      0.011196   0.998225       0.003683       0.000014  ...
#
#    top_15_accuracy_var  top_15_precision  top_15_precision_std  \
# 0             0.000874          0.996499              0.012615
# 1             0.000991          0.990049              0.016303
# 2             0.003021          0.957281              0.085145
# 3             0.000547          0.999958              0.000084
# 4             0.000093          0.996934              0.004119
#
#    top_15_precision_var  top_15_recall  top_15_recall_std top_15_recall_var  \
# 0          1.591488e-04       0.897792           0.061511          0.003784
# 1          2.657746e-04       0.841379           0.066880          0.004473
# 2          7.249714e-03       0.810801           0.123032          0.015137
# 3          7.096399e-09       0.832950           0.046302          0.002144
# 4          1.696218e-05       0.901709           0.020339          0.000414
#
#   top_15_f1 top_15_f1_std  top_15_f1_var
# 0  0.943276      0.033227       0.001104
# 1  0.907984      0.036468       0.001330
# 2  0.867570      0.066808       0.004463
# 3  0.908178      0.026373       0.000696
# 4  0.946791      0.010675       0.000114
#
# [5 rows x 116 columns]

# %%
#set examples_per_class to 0 everytime generation_mode = zero_shot
df.loc[df['generation_mode'] == 'rag', 'examples_per_class'] = 0

# %%
#filter df to only include rag and rag_few_shot
df = df[df['generation_mode'].isin(['rag', 'rag_few_shot'])]

# %%
df = df[['model_name', 'temperature', 'examples_per_class', 'folder']]

# %%
def from_folder_to_accuracy_list(folder:str)->list:
    folder = os.path.join('../..', folder)
    #find all the subfolder in folder:
    subfolders = [f.path for f in os.scandir(folder) if f.is_dir() ]
    #map subfolder to the dict conteined in results.json file
    results = []
    for subfolder in subfolders:
        with open(os.path.join(subfolder, 'results.json')) as f:
            results.append(json.load(f))
    #keep only the results where failed is False
    results = [r for r in results if not r['failed']]
    #map results to accuracy
    results = [r['results']['accuracy'] for r in results]
    return results

# %%
df.head()
# Out:
#            model_name  temperature  examples_per_class  \
# 0  gpt-4-1106-preview          0.0                  10
# 1  gpt-4-1106-preview          0.0                   2
# 2  gpt-4-1106-preview          0.0                   3
# 3  gpt-4-1106-preview          0.0                   1
# 4  gpt-4-1106-preview          0.0                   5
#
#                                               folder
# 0  experiments/task_detect_xss_simple_prompt/temp...
# 1  experiments/task_detect_xss_simple_prompt/temp...
# 2  experiments/task_detect_xss_simple_prompt/temp...
# 3  experiments/task_detect_xss_simple_prompt/temp...
# 4  experiments/task_detect_xss_simple_prompt/temp...

# %%
df['accuracy'] = df['folder'].map(from_folder_to_accuracy_list)

# %%
df.head()
# Out:
#            model_name  temperature  examples_per_class  \
# 0  gpt-4-1106-preview          0.0                  10
# 1  gpt-4-1106-preview          0.0                   2
# 2  gpt-4-1106-preview          0.0                   3
# 3  gpt-4-1106-preview          0.0                   1
# 4  gpt-4-1106-preview          0.0                   5
#
#                                               folder  \
# 0  experiments/task_detect_xss_simple_prompt/temp...
# 1  experiments/task_detect_xss_simple_prompt/temp...
# 2  experiments/task_detect_xss_simple_prompt/temp...
# 3  experiments/task_detect_xss_simple_prompt/temp...
# 4  experiments/task_detect_xss_simple_prompt/temp...
#
#                                             accuracy
# 0  [0.9832196201364558, 0.9265166881799742, 0.849...
# 1  [0.8646505624193251, 0.7354785174257791, 0.886...
# 2  [0.9484602618476858, 0.6926977687626775, 0.680...
# 3  [0.9056795131845842, 0.8601327678406786, 0.905...
# 4  [0.9392402729116726, 0.7213719343536787, 0.764...

# %%
#explode the accuracy list
df = df.explode('accuracy')
df.head()
# Out:
#            model_name  temperature  examples_per_class  \
# 0  gpt-4-1106-preview          0.0                  10
# 0  gpt-4-1106-preview          0.0                  10
# 0  gpt-4-1106-preview          0.0                  10
# 0  gpt-4-1106-preview          0.0                  10
# 0  gpt-4-1106-preview          0.0                  10
#
#                                               folder  accuracy
# 0  experiments/task_detect_xss_simple_prompt/temp...   0.98322
# 0  experiments/task_detect_xss_simple_prompt/temp...  0.926517
# 0  experiments/task_detect_xss_simple_prompt/temp...  0.849161
# 0  experiments/task_detect_xss_simple_prompt/temp...  0.951318
# 0  experiments/task_detect_xss_simple_prompt/temp...  0.980915

# %%
#reinitialize the index
df = df.reset_index(drop=False)
df.head()
# Out:
#    index          model_name  temperature  examples_per_class  \
# 0      0  gpt-4-1106-preview          0.0                  10
# 1      0  gpt-4-1106-preview          0.0                  10
# 2      0  gpt-4-1106-preview          0.0                  10
# 3      0  gpt-4-1106-preview          0.0                  10
# 4      0  gpt-4-1106-preview          0.0                  10
#
#                                               folder  accuracy
# 0  experiments/task_detect_xss_simple_prompt/temp...   0.98322
# 1  experiments/task_detect_xss_simple_prompt/temp...  0.926517
# 2  experiments/task_detect_xss_simple_prompt/temp...  0.849161
# 3  experiments/task_detect_xss_simple_prompt/temp...  0.951318
# 4  experiments/task_detect_xss_simple_prompt/temp...  0.980915

# %%
df["model_temperature"] = df["model_name"] + "_" + df["temperature"].astype(str)

# %%
df.examples_per_class.unique()
# Out:
# array([10,  2,  3,  1,  5,  0])

# %%
df.head()
# Out:
#    index          model_name  temperature  examples_per_class  \
# 0      0  gpt-4-1106-preview          0.0                  10
# 1      0  gpt-4-1106-preview          0.0                  10
# 2      0  gpt-4-1106-preview          0.0                  10
# 3      0  gpt-4-1106-preview          0.0                  10
# 4      0  gpt-4-1106-preview          0.0                  10
#
#                                               folder  accuracy  \
# 0  experiments/task_detect_xss_simple_prompt/temp...   0.98322
# 1  experiments/task_detect_xss_simple_prompt/temp...  0.926517
# 2  experiments/task_detect_xss_simple_prompt/temp...  0.849161
# 3  experiments/task_detect_xss_simple_prompt/temp...  0.951318
# 4  experiments/task_detect_xss_simple_prompt/temp...  0.980915
#
#         model_temperature
# 0  gpt-4-1106-preview_0.0
# 1  gpt-4-1106-preview_0.0
# 2  gpt-4-1106-preview_0.0
# 3  gpt-4-1106-preview_0.0
# 4  gpt-4-1106-preview_0.0

# %%
#draw boxplot  per model-temperature pair and examples_per_class
sns.set_theme(style="whitegrid")
#make figure larger
plt.figure(figsize=(20, 10))
ax = sns.boxplot(x="model_temperature", y="accuracy", hue="examples_per_class", data=df, palette="Spectral", legend = "full")
ax.set_xticklabels(ax.get_xticklabels(), rotation=30)
ax.set_xlabel("model_name, temperature")
ax.set_ylabel("accuracy")
#set legend using the hue values present in the dataset
plt.show()
# Out:
# /tmp/ipykernel_293562/4170341328.py:6: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=30)

# %%
#draw boxplot  per model-temperature pair and examples_per_class
hue_order = df.groupby('model_temperature')["model_temperature"].first().sort_values().index

sns.set_theme(style="whitegrid")
#make figure larger
plt.figure(figsize=(30, 8))
ax = sns.boxplot(x="examples_per_class", y="accuracy", hue="model_temperature", hue_order = hue_order,data=df, palette="Spectral", legend = "brief")
ax.set_xticklabels(ax.get_xticklabels(), rotation=30)
ax.set_xlabel("model_name, temperature")
ax.set_ylabel("accuracy")
#set legend using the hue values present in the dataset
plt.show()
# Out:
# /tmp/ipykernel_293562/1813412099.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=30)

# %%
#draw the catplot
sns.set_theme(style="whitegrid")
#make figure larger
plt.figure(figsize=(35, 15))
ax = sns.catplot(x="examples_per_class",col="model_temperature", y="accuracy", hue = "examples_per_class", kind="box", data=df, col_wrap =3, palette="Spectral")
#show legends with color
#set legend using the hue values present in the datase
#plt.legend(title='examples_per_class')
#plt.show()

# %%
hue_order = df.groupby('model_temperature')["model_temperature"].first().sort_values().index
#draw the catplot
sns.set_theme(style="whitegrid")
#make figure larger
plt.figure(figsize=(35, 15))
ax = sns.catplot(x="model_temperature",col="examples_per_class", y="accuracy", hue = "model_temperature", hue_order = hue_order, kind="box", data=df, col_wrap =2, palette="Spectral", legend="full")
#hide x labels
ax.set_xticklabels([])
#show legend
